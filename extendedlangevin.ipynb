# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
df = pd.read_csv("simulation_data.csv")
df
# Out:
#       F  folding_rate  unfolding_rate  \
# 0 -0.50      6.023502        0.642910
# 1 -0.25      3.941281        1.244025
# 2  0.00      2.256887        2.281420
# 3  0.25      1.228953        3.814343
# 4  0.50      0.659841        6.178414
#
#                                            t_up_list  \
# 0  [0.045500000000000096, 0.24049999999999994, 0....
# 1  [0.14, 0.27249999999999996, 0.377, 0.109999999...
# 2  [0.27149999999999996, 1.2369999999999999, 0.22...
# 3  [1.2414999999999998, 0.16549999999999998, 0.47...
# 4  [1.7229999999999999, 0.345, 3.533, 0.371999999...
#
#                                          t_down_list
# 0  [1.7839999999999998, 3.8139999999999996, 6.701...
# 1  [0.7599999999999999, 0.13749999999999996, 0.06...
# 2  [0.7835, 0.7814999999999999, 0.012999999999999...
# 3  [0.11299999999999999, 0.023500000000000076, 0....
# 4  [0.1515, 0.010999999999999899, 0.3745000000000...

# %%
df_fortran = pd.read_pickle("dati_fortran.pkl")
df_fortran
# Out:
#        F  folding_rate  unfolding_rate  \
# 0  -2.00     16.656839        0.001200
# 1  -1.50     14.096376        0.009543
# 2  -1.00      9.545452        0.077740
# 3  -0.50      4.955827        0.494080
# 4  -0.25      3.256889        0.987707
# 5   0.00      2.210126        2.262489
# 6   0.25      1.205202        3.866830
# 7   0.50      0.481963        4.884882
# 8   1.00      0.073970        9.514321
# 9   1.50      0.008748       14.466068
# 10  2.00      0.000979       18.207375
#
#                                             t_up_list  \
# 0   [0.04998799999998482, 0.10003899999992427, 0.0...
# 1   [0.04999920000000202, 0.050003000000003794, 0....
# 2   [0.1500000900000007, 0.10000040000000254, 0.14...
# 3   [0.14999997399999987, 0.19999980999999956, 0.2...
# 4   [0.25000003000000004, 0.049999950000000126, 0....
# 5   [0.451499962, 0.36549991700000006, 0.626000039...
# 6   [0.2615000009999999, 0.4604999999999999, 0.981...
# ...

# %%
plt.plot(df["F"], df["t_up_list"].apply(len), marker="o")
plt.xlabel("F pN")
plt.ylabel("N° transition +-1 ")
plt.title(" F vs N transitions PYTHON")
plt.grid(True)
plt.show()

plt.plot(df_fortran["F"], df_fortran["t_up_list"].apply(len), marker="o")
plt.xlabel("F pN")
plt.ylabel("N° transition +-1 ")
plt.title(" F vs N transitions FORTRAN")
plt.grid(True)
plt.show()
